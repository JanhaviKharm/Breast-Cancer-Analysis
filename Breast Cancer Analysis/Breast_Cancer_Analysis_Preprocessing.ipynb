# %% [markdown]
# ## Breast Cancer Analysis
# ## Preprocessing File
# ### Janhavi Anantprakash Kharmale

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(42)

# %%
#Reading the dataset
df = pd.read_csv("C:/Users/janha/Downloads/archive/data.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# #### This dataset contains 569 rows and 33 columns

# %%
#Identify and count missing values in each column of the DataFrame
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# #### We can see that the column name- Unamed:32 has 569 missing values, hence we need to drop it.

# %%
#Dropping the id column and unamed: 32 column
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 32',axis=1,inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# #### The diagnosis column which determines if a patient has symptoms of breast cancer. If the value is 'M' means they are diagnosed and if it is 'B' means they are not. Converting these value into binary. For 'M' the value will be 1 and for 'B' the value will be 0.

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1 , 'B':0})
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
corr = df.corr().round(2)

# Mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
f, ax = plt.subplots(figsize=(20, 20))

# Draw the heatmap
sns.heatmap(corr, mask=mask, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.tight_layout()

# %% [markdown]
# # Strong Positive Correlations:
#
# Features in the "worst" category, such as "radius worst," "texture worst," "perimeter worst," "area worst," "smoothness worst," "compactness worst," "concavity worst," "concave points worst," "symmetry worst," and "fractal_dimension worst" all display high positive correlations with their respective counterparts in the "mean" category (e.g., "radius mean," "texture mean," etc.). This indicates significant redundancy in the information these pairs of features providey_mean."

# %% [markdown]
# # OtherNoteworthy Correlations:
#
#  1)"perimeter mean" is notably positively correlated with "radius mean."
#  2)"perimeter_se" demonstrates a strong positive correlation with "area_mean."
#  3)"area_mean" and "area_se" exhibit a substantial positive correlation.
# There is a clear correlation between "concavity_mean" and "concave points_mean," and a similar correlation between "concave points_mean" and "concavity_mean." Additionally, "concave points_se" is positively correlated with "concavity_mean."

# %%
# Drop all the columns with high correlation
cols = ['radius_worst', 
        'texture_worst', 
        'perimeter_worst', 
        'area_worst', 
        'smoothness_worst', 
        'compactness_worst', 
        'concavity_worst',
        'concave points_worst', 
        'symmetry_worst', 
        'fractal_dimension_worst',
        'perimeter_mean',
        'perimeter_se', 
        'area_mean', 
        'area_se',
        'concavity_mean',
        'concavity_se', 
        'concave points_mean', 
        'concave points_se' ]
df = df.drop(cols, axis=1)

# verify remaining columns
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'smoothness_se', 'compactness_se',
#        'symmetry_se', 'fractal_dimension_se'],
#       dtype='object')

# %%
# Draw the heatmap again, with the new correlation matrix
corr = df.corr().round(2)
mask = np.zeros_like(corr, dtype= bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.tight_layout()

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0            1        17.99         10.38          0.11840           0.27760
# 1            1        20.57         17.77          0.08474           0.07864
# 2            1        19.69         21.25          0.10960           0.15990
# 3            1        11.42         20.38          0.14250           0.28390
# 4            1        20.29         14.34          0.10030           0.13280
# ..         ...          ...           ...              ...               ...
# 564          1        21.56         22.39          0.11100           0.11590
# 565          1        20.13         28.25          0.09780           0.10340
# 566          1        16.60         28.08          0.08455           0.10230
# 567          1        20.60         29.33          0.11780           0.27700
# 568          0         7.76         24.54          0.05263           0.04362
#
# ...

# %%
#Converting to a csv file 
df.to_csv(r"C:\Users\janha\Downloads\archive\breast_cancer_data.csv", index=False)

# %% [markdown]
# In this file we have performed the preprocessing steps required for the dataset and converted to a csv file for further model fitting process which will be performed in the next notebook.
